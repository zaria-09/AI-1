# %% [markdown]
# # What proportion of TV shows on TMDB are classified as "Comedy"?

# %%
import pandas as pd
import requests
import random
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
headers = {
    "Authorization" : "bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiI4NjNmOGEyMTIzZTg1NzU2YzkxY2Q3OTYyYWI3ZmUxNSIsIm5iZiI6MTc2MjE4NzY5Ny43NzcsInN1YiI6IjY5MDhkOWIxMGViMDBiZDMyMGUxMzMwYSIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.DYdVbr-bcZEfy12V9hvvW_56lHLliAAGkz7o0IDfpZY",
    "accept" : "application/json"
}

# %%
props = []
count = 0

while count < 100:
    print("count",count)
    num_of_sample = 0
    C_score = []
    while num_of_sample < 30:
        tvshowid = random.randint(0, 300000)
        endpoint = f"https://api.themoviedb.org/3/tv/{tvshowid}"
        response = requests.get(endpoint, headers = headers)
        
        while response.status_code != 200:
            tvshowid = random.randint(0, 300000)
            endpoint = f"https://api.themoviedb.org/3/tv/{tvshowid}"
            response = requests.get(endpoint, headers = headers)
            if response.status_code == 429:
                time.sleep(2) 
            continue
        data = response.json()
        genres = data.get("genres", [])
        is_com = 0
        for genre in genres:
            if genre['name'] == "Comedy":
                is_com = 1
        C_score.append(is_com)
        num_of_sample += 1
    
    proportion = sum(C_score) / len(C_score)
    props.append(proportion)
    count += 1
# Out:
# count 0
# count 1
# count 2
# count 3
# count 4
# count 5
# count 6
# count 7
# count 8
# count 9
# count 10
# count 11
# count 12
# count 13
# count 14
# count 15
# count 16
# count 17
# count 18
# count 19
# count 20
# count 21
# count 22
# count 23
# count 24
# count 25
# count 26
# count 27
# count 28
# count 29
# count 30
# count 31
# count 32
# count 33
# count 34
# count 35
# count 36
# count 37
# count 38
# count 39
# count 40
# count 41
# count 42
# count 43
# count 44
# count 45
# count 46
# count 47
# count 48
# count 49
# count 50
# count 51
# count 52
# count 53
# count 54
# count 55
# count 56
# count 57
# count 58
# count 59
# count 60
# count 61
# count 62
# count 63
# count 64
# count 65
# count 66
# count 67
# count 68
# count 69
# count 70
# count 71
# count 72
# count 73
# count 74
# count 75
# count 76
# count 77
# count 78
# count 79
# count 80
# count 81
# count 82
# count 83
# count 84
# count 85
# count 86
# count 87
# count 88
# count 89
# count 90
# ...

# %%
sns.histplot(props)
plt.title("Distribution of Comedy Proportions")
plt.xlabel("Proportion Comedy")
# Out:
# Text(0.5, 0, 'Proportion Comedy')

# %%
import numpy as np
std_dev = np.std(props) 
std_dev
# Out:
# 0.06644881070752466

# %%
p = np.mean(props)
theoretical_sd = np.sqrt(p * (1 - p) / 30)
theoretical_sd
# Out:
# 0.06403815413630522

# %%
p_estimate = np.mean(props)
p_estimate
# Out:
# 0.14366666666666666

# %% [markdown]
# Answer: 14.4% of TV shows on TMDB are classified as "Comedy" based on my simulation. the empirical standard deviation is 6.64% and the theoretical standard deviation is 6.40%. my graph looks normal because it looks bell curved, maybe a bit skewed
